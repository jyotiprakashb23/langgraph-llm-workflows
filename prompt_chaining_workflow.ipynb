# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# initialize Gemini model
model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",  # fast + free-tier friendly
    temperature=0.7
)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    outline_prompt = f"Create a detailed outline for a blog on topic : {state['title']}"
    outline = model.invoke(outline_prompt).text
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    content_prompt = f"Write a blog based on the following outline : {state['outline']}"
    content = model.invoke(content_prompt).text
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

# add nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# add edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

# compile graph
workflow = graph.compile()

# %%
initial_state = BlogState(title="The impact of AI on modern education")
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# # The Classroom Revolution: How AI is Redefining Modern Education
#
# Close your eyes and think back to a classroom from twenty years ago. You likely see rows of wooden desks, a chalkboard covered in dusty equations, and a teacher at the front of the room holding a heavy textbook. Fast forward to today, and the scene is unrecognizable. Students are equipped with tablets, lessons are delivered via interactive screens, and—most significantly—a silent, digital engine is running in the background: Artificial Intelligence.
#
# The rapid adoption of Generative AI, spearheaded by tools like ChatGPT, along with sophisticated adaptive learning platforms, has moved AI from the realm of science fiction to the front row of the classroom. While AI offers unprecedented opportunities for personalized learning and administrative efficiency, it also necessitates a fundamental rethink of academic integrity and the essential human role in teaching.
#
# In this post, we will explore how AI is personalizing the student experience, empowering teachers to become mentors, breaking down accessibility barriers, and presenting a new set of ethical challenges we must navigate.
#
# ---
#
# ## The Power of Personalized Learning
#
# For decades, the "factory model" of education—where every student learns the same material at the same pace—was the only feasible way to manage large groups. AI has finally shattered that mold.
#
# **Adaptive Learning Platforms**
# Tools like Khan Academy and Duolingo use AI algorithms to act as a personal guide. If a student masters a math concept quickly, the AI skips ahead to keep them engaged. If they struggle with a specific grammar rule, the system provides extra practice and alternative explanations. It’s education that breathes and moves with the student.
#
# **Closing the Gap in Real-Time**
# Traditionally, a teacher might not realize a student is falling behind until they fail a midterm exam. AI changes this by identifying specific knowledge gaps in real-time. By analyzing daily interactions, these systems can flag exactly where a student’s understanding is fracturing, allowing for immediate intervention.
#
# **The "24/7 Tutor"**
# Learning doesn't stop when the school bell rings, but teacher availability does. AI-powered chatbots now serve as on-demand tutors, providing instant support for late-night study sessions. Whether a student needs help balancing a chemical equation or understanding a Shakespearean sonnet, help is now just a prompt away.
#
# ---
#
# ## Empowering Educators: Shifting from Graders to Mentors
#
# There is a common fear that AI will replace teachers. In reality, AI is poised to save the profession by automating the "drudge work" and allowing teachers to return to what they love: mentoring students.
#
# *   **Automating Administrative Tasks:** Grading multiple-choice tests, tracking attendance, and managing lesson schedules take up hours of a teacher’s week. AI can handle these tasks in seconds, freeing up time for one-on-one student interaction.
# *   **Data-Driven Insights:** AI analytics can scan an entire grade level to identify "at-risk" students who may be showing early signs of disengagement or academic struggle, allowing for proactive support.
# *   **Enhanced Lesson Planning:** Teachers are using AI as a creative co-pilot. From generating custom quizzes to rewriting a complex scientific article into a version suitable for a 5th-grade reading level, AI acts as a powerful force-multiplier for curriculum design.
#
# > **Case Study: Jill Watson at Georgia Tech**
# > In 2016, Georgia Tech introduced "Jill Watson," an AI teaching assistant. Jill was so effective at answering student questions in an online forum that many students didn't realize she wasn't human until the end of the semester. This proved that AI can handle routine inquiries, leaving human professors free to tackle complex philosophical and technical discussions.
#
# ---
#
# ## Breaking Barriers: Accessibility and Inclusion
#
# Perhaps the most noble application of AI in education is its ability to make learning accessible to everyone, regardless of physical or linguistic barriers.
#
# For students with visual or auditory impairments, AI tools providing speech-to-text and real-time captioning are life-changing. Furthermore, AI is democratizing language. Real-time translation tools allow ESL (English as a Second Language) students to follow a mainstream curriculum in their native tongue while they build their English proficiency.
#
# On a global scale, AI-powered platforms are bringing high-quality educational resources to remote or underserved regions where there may be a shortage of qualified teachers, effectively "exporting" top-tier education to every corner of the globe.
#
# ---
#
# ## The Challenges and Ethical Dilemmas
#
# Despite the benefits, the "ChatGPT elephant in the room" cannot be ignored. The rise of AI brings significant friction to the traditional academic world.
#
# 1.  **Academic Integrity:** When an AI can write a passing essay in ten seconds, the traditional homework model is broken. Schools are now shifting toward "authentic assessment"—oral exams, in-class handwritten essays, and project-based learning that AI cannot easily replicate.
# 2.  **Data Privacy:** AI thrives on data. Collecting vast amounts of information on student performance and behavior raises serious questions about who owns that data and how it is protected from commercial exploitation or security breaches.
# 3.  **The Digital Divide:** There is a growing risk that AI will widen the inequality gap. While well-funded private schools may integrate cutting-edge AI labs, students in underfunded districts or developing nations may be left further behind without access to the necessary hardware and high-speed internet.
# 4.  **The Loss of Human Connection:** Education is a social-emotional process. If students spend all their time interacting with screens and algorithms, we risk losing the vital mentorship and character-building that only a human teacher can provide.
#
# ---
#
# ## Preparing for the Future: AI Literacy
#
# As we look ahead, the goal of education must shift. If information is now a commodity provided by AI, the value of education must lie in how we *use* that information.
#
# We are seeing a shift in curriculum toward **AI Literacy**. This includes teaching "prompt engineering"—the art of communicating effectively with AI—and fostering critical thinking so students can identify AI hallucinations or biases. Schools must teach students to use AI responsibly and skeptically, preparing them for a job market where AI collaboration will be a standard requirement rather than an optional skill.
#
# ---
#
# ## Conclusion: Human + AI
#
# The future of education is not a battle of "Human vs. Machine." Instead, it is a partnership. AI is a tool—a powerful, transformative, and complex tool—but it is not a replacement for the inspiration, empathy, and wisdom of a great teacher.
#
# By embracing AI to handle the analytical and administrative heavy lifting, we can create a more inclusive, personalized, and efficient educational system. The classroom of the future won't just be about what we learn, but how we use our unique human creativity to build upon the foundation that AI helps us lay.
#
# **How has AI changed your learning or teaching experience? Are you excited about the possibilities, or worried about the risks? Let us know in the comments below!**
#
# ---
#
# ### Quick Tips: 3 Ways Students Can Use AI Responsibly
# *   **The Socratic Tutor:** Instead of asking AI for the answer, ask it to "act as a tutor and guide me through the steps to solve this problem myself."
# *   **The Brainstormer:** Use AI to generate five different perspectives on a topic to help overcome writer's block.
# *   **The Fact-Checker:** Always verify AI-generated citations. Use AI to find a lead, but use a library database to find the truth.

# %%
model.invoke('How far is moon from the earth?')
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Because the Moon orbits the Earth in an elliptical (oval-shaped) path, the distance between them is constantly changing. \n\nHere are the key measurements:\n\n*   **Average Distance:** Approximately **238,855 miles** (384,400 kilometers).\n*   **Closest Point (Perigee):** About **225,623 miles** (363,104 kilometers). This is when we often see a "Supermoon."\n*   **Farthest Point (Apogee):** About **252,088 miles** (405,504 kilometers).\n\n### To put that distance into perspective:\n*   **The "30 Earths" Rule:** You could fit about 30 Earth-sized planets in the gap between the Earth and the Moon.\n*   **Light Speed:** It takes light (and radio signals) about **1.3 seconds** to travel from the Moon to the Earth.\n*   **Travel Time:** If you were driving a car at a constant 60 mph (97 km/h), it would take you about **six months** to get there. It took the Apollo astronauts about **three days** to reach the Moon via rocket.\n\n**Fun Fact:** The Moon is slowly moving away from Earth at a rate of about **1.5 inches (3.8 centimeters) per year.**', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c6aa3-8abd-7471-aa02-86f1e155f941-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 547, 'total_tokens': 556, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 246}})
